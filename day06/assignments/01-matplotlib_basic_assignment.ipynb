# %% [markdown]
# # Matplotlib exercices

# %% [markdown]
# In this exercise, we are using Pandas and Matplotlib to visualize Company Sales Data. The data is located under the folder `../data/company_sales_data.csv`.
#
# ![company_sales_data](../data/company_sales_data.webp)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df = pd.read_csv("../data/company_sales_data.csv")
df
# Out:
#     month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0              1       2500      1500        5200         9200     1200
# 1              2       2630      1200        5100         6100     2100
# 2              3       2140      1340        4550         9550     3550
# 3              4       3400      1130        5870         8870     1870
# 4              5       3600      1740        4560         7760     1560
# 5              6       2760      1555        4890         7490     1890
# 6              7       2980      1120        4780         8980     1780
# 7              8       3700      1400        5860         9960     2860
# 8              9       3540      1780        6100         8100     2100
# 9             10       1990      1890        8300        10300     2300
# 10            11       2340      2100        7300        13300     2400
# 11            12       2900      1760        7400        14400     1800
#
#     moisturizer  total_units  total_profit
# 0          1500        21100        211000
# 1          1200        18330        183300
# 2          1340        22470        224700
# 3          1130        22270        222700
# 4          1740        20960        209600
# 5          1555        20140        201400
# 6          1120        29550        295500
# 7          1400        36140        361400
# 8          1780        23400        234000
# 9          1890        26670        266700
# 10         2100        41280        412800
# 11         1760        30020        300200

# %% [markdown]
# ## Exercise 1
# **Read Total profit of all months and show it using a line plot**
#
# Total profit data provided for each month. Generated line plot must include the following properties:
# - X label name = Month Number
# - Y label name = Total profit
# The line plot graph should look like this.
#
# **Expected output**
#
# <img src="../data/Company_profit_per_month.png" alt="Company_profit_per_month" style="width: 500px;"/>

# %%
plt.figure(figsize=(10, 5))
plt.plot(df["month_number"], df["total_profit"])
x = np.arange(1,13,1)
plt.xticks(x)
plt.title("Company profit per month")
plt.xlabel("Month number")
plt.ylabel("Profit in dollar")
# Out:
# Text(0, 0.5, 'Profit in dollar')

# %% [markdown]
# ## Exercise 2
# **Get total profit of all months and show line plot with the following Style properties**
# - Line Style dotted and Line-color should be red
# - Show legend at the lower right location.
# - X label name = Month Number
# - Y label name = Sold units number
# - Add a circle marker.
# - Line marker color as read
# - Line width should be 3
#
# **Expected output**
#
# <img src="../data/company_sales_data_of_last_year.png" alt="company_sales_data_of_last_year" style="width: 700px;"/>

# %%
plt.figure(figsize=(11, 5))
plt.plot(df["month_number"], df["total_profit"], "r--", label="Profit data of last year", linewidth=3, marker="o", markerfacecolor="#000000")
plt.legend(loc="lower right")
plt.xlabel("Month Number")
plt.xticks(np.arange(1,13,1))
plt.ylabel("Sold units number")
plt.show()

# %% [markdown]
# ## Exercise 3
# **Read all product sales data and show it  using a multiline plot**
# Display the number of units sold per month for each product using multiline plots. (i.e., Separate Plotline for each product ).
# **Expected output**
#
# <img src="../data/sales_data.png" alt="sales_data" style="width: 500px;"/>

# %%
plt.figure(figsize=(8, 7))
plt.plot(df["month_number"], df["facecream"], "r", label="Facecream Sales Data", marker="o")
plt.plot(df["month_number"], df["facewash"], "orange", label="Facewash Sales Data", marker="o")
plt.plot(df["month_number"], df["toothpaste"], "brown", label="Toothpaste Sales Data", marker="o")
plt.plot(df["month_number"], df["bathingsoap"], "b", label="Bathingsoap Sales Data", marker="o")
plt.plot(df["month_number"], df["shampoo"], "g", label="Shampoo Sales Data", marker="o")
plt.plot(df["month_number"], df["moisturizer"], "purple", label="Moisturizer Sales Data", marker="o")
plt.legend(loc="upper left")

# %% [markdown]
# ## Exercise 4
# **Read toothpaste sales data of each month and show it using a scatter plot**
# Also, add a grid in the plot. gridline style should “–“.
#
# **Expected output**
#
# <img src="../data/Tooth_paste_Sales_data.png" alt="sales_data" style="width: 700px;"/>

# %%
plt.figure(figsize=(8, 5))
plt.plot(df["month_number"], df["toothpaste"], "o", label="Toothpaste Sales Data", marker="o")
plt.legend(loc="upper left")
plt.grid(True, linestyle="--")
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_9956\2384338544.py:2: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   plt.plot(df["month_number"], df["toothpaste"], "o", label="Toothpaste Sales Data", marker="o")

# %% [markdown]
# ## Exercise 5
# **Read face cream and facewash product sales data and show it using the bar chart**
# The bar chart should display the number of units sold per month for each product. Add a separate bar for each product in the same chart.
#
# **Expected output**
#
# <img src="../data/Facewash_and_facecream_sales_data.png" alt="sales_data" style="width: 700px;"/>

# %%
plt.figure(figsize=(8, 5))
lengh= 0.3

plt.bar(df["month_number"] - lengh/2, df["facecream"], lengh, color="b", label="Facecreamsales sales data")
plt.bar(df["month_number"] + lengh/2, df["facewash"], lengh, color="orange", label="Facewash sales data")
plt.legend(loc="upper left")
plt.xticks(df["month_number"])
plt.grid(True, linestyle="--")

# %% [markdown]
# ## Exercise 6
# **Read sales data of bathing soap of all months and show it using a bar chart. Save this plot to your hard disk**
#
# **Expected output**
#
# <img src="../data/sales_data_of_bathingsoap.png" alt="sales_data_of_bathingsoap" style="width: 700px;"/>

# %%
plt.figure(figsize=(8, 5))
plt.bar(df["month_number"], df["bathingsoap"],)
plt.xlabel("Month Number")
plt.ylabel("Sales units in number")
plt.grid(linestyle="--")
plt.savefig("../../../../../Downloads/Soap Sales.png")

# %% [markdown]
# ## Exercise 7
# **Read the total profit of each month and show it using the histogram to see the most common profit ranges**
#
# **Expected output**
#
# <img src="../data/Profit_data.png" alt="Profit_data" style="width: 700px;"/>

# %%
plt.figure(figsize=(11, 6))
plt.hist(df["total_profit"], bins=[175000,200000,225000, 250000, 300000, 350000], label="Profit data")
plt.legend(loc="upper left")

# %% [markdown]
# ## Exercise 8
# **Calculate total sale data for last year for each product and show it using a Pie chart**
#
# *Note: In Pie chart display Number of units sold per year for each product in percentage.*
#
# **Expected output**
#
# <img src="../data/sales_data_pi_chart.png" alt="sales_data_pi_chart" style="width: 700px;"/>

# %%
def units_per_year(my_df):
    total = 0
    for i in my_df:
        total += i
    return total
units_list = [units_per_year(df["facecream"]), units_per_year(df["facewash"]), units_per_year(df["toothpaste"]), units_per_year(df["bathingsoap"]), units_per_year(df["shampoo"]), units_per_year(df["moisturizer"])]
labeles = ["Facecream", "Facewash", "Toothpaste", "Bathingsoap", "Shampoo", "Moisturizer"]
plt.figure(figsize=(10,12))
plt.pie(x=units_list, labels=labeles, autopct="%.1f%%")
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# ## Exercise 9
# **Read Bathing soap facewash of all months and display it using the Subplot**
#
# **Expected output**
#
# <img src="../data/Sales_data_of_a_facewash.png" alt="Sales_data_of_a_facewash" style="width: 700px;"/>

# %%
plt.figure(figsize=(11, 6))
plt.subplot(2,1,2)
plt.plot(df["month_number"], df["facewash"], "red", linewidth=3, marker="o")
plt.title("Sales data of facewash")

plt.subplot(2,1,1)
plt.plot(df["month_number"], df["bathingsoap"], "black", linewidth=3, marker="o")
plt.title("Sales data of bathingsoap")
# Out:
# Text(0.5, 1.0, 'Sales data of bathingsoap')

# %% [markdown]
# ## Exercise 10
# **Read all product sales data and show it using the stack plot**
#
# **Expected output**
#
# <img src="../data/product_sales_stack_plot.png" alt="product_sales_stack_plot" style="width: 700px;"/>

# %%
plt.figure(figsize=(11,6))
plt.stackplot(df["month_number"], df["facecream"], df["facewash"], df["toothpaste"], df["bathingsoap"], df["shampoo"], df["moisturizer"], colors=["fuchsia", "deepskyblue", "red", "black", "green", "y"], labels=["Face Cream", "Face Wash", "Toothpaste", "Bathingsoap", "Shampoo", "Moisturizer"])
plt.xticks(df["month_number"])
plt.legend(loc="upper left")
plt.show()
